# %%
import joblib

load_model = joblib.load('best_iris_random_forest_model.pkl')
print("Model loaded:",load_model.get_params())
# Out:
# Model loaded: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 200, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
data = load_iris()

get_data = data.data
target = data.target

X = get_data
y= target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y_pred = load_model.predict(X_test)
print("Précision sur l'ensemble de test (modèle chargé) :", accuracy_score(y_test, y_pred))
# Out:
# Précision sur l'ensemble de test (modèle chargé) : 1.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix


# Générer la matrice de confusion
cm = confusion_matrix(y_test, y_pred)

# Afficher la heatmap
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=data.target_names,
            yticklabels=data.target_names)
plt.title("Matrice de confusion - RandomForest (modèle chargé)")
plt.xlabel("Prédictions")
plt.ylabel("Vérités terrain")
plt.show()
# Out:
# C:\Users\Ponss\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # 🌸 Iris Classification with RandomForest
#
# This notebook demonstrates a Machine Learning workflow using the **Iris dataset**.
# We trained a **RandomForestClassifier** with hyperparameter tuning using GridSearchCV.
#
# ---
#
# ## 📊 Confusion Matrix Analysis
#
# **English:**
# The confusion matrix shows that the RandomForest model perfectly classifies all three Iris species (`setosa`, `versicolor`, and `virginica`). Since all predictions fall on the diagonal, the model achieves 100% accuracy on the test set. This indicates strong generalization performance for this dataset.
#
# **한국어 (Korean):**
# 혼동 행렬(Confusion Matrix)은 RandomForest 모델이 세 가지 붓꽃 품종(`setosa`, `versicolor`, `virginica`)을 완벽하게 분류했음을 보여줍니다. 모든 예측이 대각선에 위치하여 테스트 데이터셋에서 100% 정확도를 달성했습니다. 이는 해당 데이터셋에 대해 모델이 뛰어난 일반화 성능을 보인다는 것을 의미합니다.
